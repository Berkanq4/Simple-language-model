# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

################################################################
# Load and Tokenize Data
##############################################################

# Load the text file
with open('last_data.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# Character- level tokenization
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(f"Unique characters in the dataset: {vocab_size}")

#char style mapping but word mapping could also be used, or sub-word tokenization is probably the most likeable.
# Create mappings
char_to_idx = {ch: i for i, ch in enumerate(chars)}
idx_to_char = {i: ch for i, ch in enumerate(chars)}

# Encode the entire text into integers
encoded = [char_to_idx[ch] for ch in text]
encoded = torch.tensor(encoded, dtype=torch.long)

# Train-validation split
split_ratio = 0.9
n = int(split_ratio * len(encoded))
train_data = encoded[:n]
val_data = encoded[n:]


##############################################################
# Dataset Class
##################################################3

class TextDataset(Dataset):
    def __init__(self, data, block_size):
        self.data = data
        self.block_size = block_size

    def __len__(self):
        return len(self.data) - self.block_size

    def __getitem__(self, idx):
        x = self.data[idx:idx+self.block_size]
        y = self.data[idx+1:idx+self.block_size+1]
        return x, y

block_size = 32
train_dataset = TextDataset(train_data, block_size)
val_dataset = TextDataset(val_data, block_size)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, drop_last=True)

######################################################
# MiniGPT Model
#########################################################

class MiniGPT(nn.Module):
    def __init__(self, vocab_size, block_size, embedding_dim, num_heads, num_layers, ff_hidden_mult):
        super().__init__()
        self.token_embed = nn.Embedding(vocab_size, embedding_dim)
        self.pos_embed = nn.Embedding(block_size, embedding_dim)
        self.blocks = nn.ModuleList([
            TransformerBlock(embedding_dim, num_heads, ff_hidden_mult) for _ in range(num_layers)
        ])
        self.ln_f = nn.LayerNorm(embedding_dim)
        self.head = nn.Linear(embedding_dim, vocab_size, bias=False)

    def forward(self, idx):
        B, T = idx.shape
        token_embeddings = self.token_embed(idx)  #(B, T, C)
        positions = torch.arange(0, T, device=idx.device).unsqueeze(0)  #(1, T)
        positional_embeddings = self.pos_embed(positions)  #(1, T, C)
        x = token_embeddings + positional_embeddings  #(B, T, C)
        for block in self.blocks:
            x = block(x)
        x = self.ln_f(x)  #(B, T, C)
        logits = self.head(x)  #(B, T, vocab_size)
        return logits

class TransformerBlock(nn.Module):
    def __init__(self, embedding_dim, num_heads, ff_hidden_mult):
        super().__init__()
        self.ln1 = nn.LayerNorm(embedding_dim)
        self.attn = MultiHeadAttention(embedding_dim, num_heads)
        self.ln2 = nn.LayerNorm(embedding_dim)
        self.ff = FeedForward(embedding_dim, ff_hidden_mult)

    def forward(self, x):
        x = x + self.attn(self.ln1(x))
        x = x + self.ff(self.ln2(x))
        return x

class MultiHeadAttention(nn.Module):
    def __init__(self, embedding_dim, num_heads):
        super().__init__()
        assert embedding_dim % num_heads == 0
        self.num_heads = num_heads
        self.head_dim = embedding_dim // num_heads
        self.qkv = nn.Linear(embedding_dim, embedding_dim * 3)
        self.output = nn.Linear(embedding_dim, embedding_dim)

    def forward(self, x):
        B, T, C = x.shape
        qkv = self.qkv(x).reshape(B, T, 3, self.num_heads, self.head_dim).permute(2, 0, 3, 1, 4)
        q, k, v = qkv.unbind(0)  #each of them is (B, num_heads, T, head_dim)
        scores = (q @ k.transpose(-2, -1)) / (self.head_dim ** 0.5)  #(B, num_heads, T, T)
        mask = torch.tril(torch.ones(T, T, device=x.device)).unsqueeze(0).unsqueeze(0)
        scores = scores.masked_fill(mask == 0, float('-inf'))
        att = torch.softmax(scores, dim=-1)
        out = (att @ v).transpose(1, 2).reshape(B, T, C)
        return self.output(out)

class FeedForward(nn.Module):
    def __init__(self, embedding_dim, ff_hidden_mult):
        super().__init__()
        hidden_dim = embedding_dim * ff_hidden_mult
        self.net = nn.Sequential(
            nn.Linear(embedding_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, embedding_dim)
        )

    def forward(self, x):
        return self.net(x)

####################################################
# Training Setup
#########################################################

device = 'cuda' if torch.cuda.is_available() else 'cpu'

vocab_size = len(chars)
embedding_dim = 128 #these parameters may be fine-tuned.
num_heads = 4
num_layers = 2
ff_hidden_mult = 4

model = MiniGPT(vocab_size, block_size, embedding_dim, num_heads, num_layers, ff_hidden_mult).to(device)
optimizer = optim.Adam(model.parameters(), lr=3e-4)
criterion = nn.CrossEntropyLoss()

#############################################
# Training Loop
##################################################

model.train()
num_epochs = 1  #number of times it repeats
for epoch in range(num_epochs):
    for step, (x_batch, y_batch) in enumerate(train_loader):
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        logits = model(x_batch)  #(B, T, vocab_size)
        B, T, V = logits.shape
        loss = criterion(logits.view(B*T, V), y_batch.view(B*T))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if step % 100 == 0:
            print(f"Epoch {epoch}, Step {step}, Loss: {loss.item():.4f}")

################################################################
# Evaluation
###############################################################

model.eval()
val_loss = 0
val_steps = 0
with torch.no_grad():
    for x_batch, y_batch in val_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)
        logits = model(x_batch)
        B, T, V = logits.shape #split the logits according to its shape
        loss = criterion(logits.view(B*T, V), y_batch.view(B*T))
        val_loss += loss.item()
        val_steps += 1
val_loss /= val_steps
print(f"Validation loss: {val_loss:.4f}")

##############################################################
# Text Generation
##############################################################

context = torch.tensor([[char_to_idx['H']]], dtype=torch.long).to(device)  # Start with any letter
generated = context.tolist()[0]

model.eval()
with torch.no_grad():
    for _ in range(100):  #Generate 100 characters
        logits = model(context)  #(1, T, vocab_size)
        last_logits = logits[0, -1, :]  #(vocab_size,)
        probs = torch.softmax(last_logits, dim=-1)
        next_token = torch.multinomial(probs, num_samples=1)
        generated.append(next_token.item())
        context = torch.tensor([generated[-block_size:]], dtype=torch.long).to(device)

generated_text = ''.join(idx_to_char[idx] for idx in generated)
print("Generated text:")
print(generated_text)
# Out:
# Unique characters in the dataset: 75
# Epoch 0, Step 0, Loss: 4.4044
# Epoch 0, Step 100, Loss: 2.7750
# Epoch 0, Step 200, Loss: 2.6739
# Epoch 0, Step 300, Loss: 2.5266
# Epoch 0, Step 400, Loss: 2.3911
# Epoch 0, Step 500, Loss: 2.3605
# Epoch 0, Step 600, Loss: 2.1128
# Epoch 0, Step 700, Loss: 2.2691
# Epoch 0, Step 800, Loss: 2.0592
# Epoch 0, Step 900, Loss: 2.0888
# Epoch 0, Step 1000, Loss: 2.0338
# Epoch 0, Step 1100, Loss: 1.9427
# Epoch 0, Step 1200, Loss: 1.9500
# Epoch 0, Step 1300, Loss: 1.9116
# Epoch 0, Step 1400, Loss: 1.8988
# Epoch 0, Step 1500, Loss: 1.8699
# Epoch 0, Step 1600, Loss: 1.9773
# Epoch 0, Step 1700, Loss: 1.9243
# Epoch 0, Step 1800, Loss: 1.9980
# Epoch 0, Step 1900, Loss: 1.8662
# Epoch 0, Step 2000, Loss: 1.9142
# Epoch 0, Step 2100, Loss: 1.9270
# Epoch 0, Step 2200, Loss: 1.8875
# Epoch 0, Step 2300, Loss: 1.8200
# Epoch 0, Step 2400, Loss: 1.9507
# Epoch 0, Step 2500, Loss: 1.8174
# Epoch 0, Step 2600, Loss: 1.6995
# Epoch 0, Step 2700, Loss: 1.9164
# Epoch 0, Step 2800, Loss: 1.8613
# Epoch 0, Step 2900, Loss: 1.8229
# Epoch 0, Step 3000, Loss: 1.7111
# Epoch 0, Step 3100, Loss: 1.8322
# Epoch 0, Step 3200, Loss: 1.6059
# Epoch 0, Step 3300, Loss: 1.6159
# Epoch 0, Step 3400, Loss: 1.7226
# Epoch 0, Step 3500, Loss: 1.6702
# Epoch 0, Step 3600, Loss: 1.8653
# Epoch 0, Step 3700, Loss: 1.7099
# Epoch 0, Step 3800, Loss: 1.8245
# Epoch 0, Step 3900, Loss: 1.6763
# Epoch 0, Step 4000, Loss: 1.7671
# Epoch 0, Step 4100, Loss: 1.5793
# Epoch 0, Step 4200, Loss: 1.7131
# Epoch 0, Step 4300, Loss: 1.6167
# Epoch 0, Step 4400, Loss: 1.6579
# Epoch 0, Step 4500, Loss: 1.7123
# Epoch 0, Step 4600, Loss: 1.6067
# Epoch 0, Step 4700, Loss: 1.6735
# Epoch 0, Step 4800, Loss: 1.7227
# Epoch 0, Step 4900, Loss: 1.7199
# Epoch 0, Step 5000, Loss: 1.5377
# Epoch 0, Step 5100, Loss: 1.6441
# Epoch 0, Step 5200, Loss: 1.7475
# Epoch 0, Step 5300, Loss: 1.7438
# Epoch 0, Step 5400, Loss: 1.6073
# Epoch 0, Step 5500, Loss: 1.8079
# Epoch 0, Step 5600, Loss: 1.6278
# Epoch 0, Step 5700, Loss: 1.6748
# Epoch 0, Step 5800, Loss: 1.7058
# Epoch 0, Step 5900, Loss: 1.6816
# Epoch 0, Step 6000, Loss: 1.7007
# Epoch 0, Step 6100, Loss: 1.6659
# Epoch 0, Step 6200, Loss: 1.7473
# Epoch 0, Step 6300, Loss: 1.5154
# Epoch 0, Step 6400, Loss: 1.6823
# Epoch 0, Step 6500, Loss: 1.6471
# Epoch 0, Step 6600, Loss: 1.6373
# Epoch 0, Step 6700, Loss: 1.6664
# Epoch 0, Step 6800, Loss: 1.6116
# Epoch 0, Step 6900, Loss: 1.5442
# Epoch 0, Step 7000, Loss: 1.7139
# Epoch 0, Step 7100, Loss: 1.6125
# Epoch 0, Step 7200, Loss: 1.6457
# Epoch 0, Step 7300, Loss: 1.6683
# Epoch 0, Step 7400, Loss: 1.5401
# Epoch 0, Step 7500, Loss: 1.5384
# Epoch 0, Step 7600, Loss: 1.5917
# Epoch 0, Step 7700, Loss: 1.6335
# Epoch 0, Step 7800, Loss: 1.6141
# Epoch 0, Step 7900, Loss: 1.5876
# Epoch 0, Step 8000, Loss: 1.6579
# Epoch 0, Step 8100, Loss: 1.4857
# Epoch 0, Step 8200, Loss: 1.5848
# Epoch 0, Step 8300, Loss: 1.5300
# Epoch 0, Step 8400, Loss: 1.4998
# Epoch 0, Step 8500, Loss: 1.4883
# Epoch 0, Step 8600, Loss: 1.6830
# Epoch 0, Step 8700, Loss: 1.5504
# Epoch 0, Step 8800, Loss: 1.6216
# Epoch 0, Step 8900, Loss: 1.4734
# Epoch 0, Step 9000, Loss: 1.5630
# Epoch 0, Step 9100, Loss: 1.6725
# Epoch 0, Step 9200, Loss: 1.5852
# Epoch 0, Step 9300, Loss: 1.5608
# Epoch 0, Step 9400, Loss: 1.5713
# Epoch 0, Step 9500, Loss: 1.5674
# Epoch 0, Step 9600, Loss: 1.5146
# Epoch 0, Step 9700, Loss: 1.6408
# Epoch 0, Step 9800, Loss: 1.5591
# Epoch 0, Step 9900, Loss: 1.5399
# Epoch 0, Step 10000, Loss: 1.6016
# Epoch 0, Step 10100, Loss: 1.5191
# Epoch 0, Step 10200, Loss: 1.4886
# Epoch 0, Step 10300, Loss: 1.5138
# Epoch 0, Step 10400, Loss: 1.5292
# Epoch 0, Step 10500, Loss: 1.4459
# Epoch 0, Step 10600, Loss: 1.4383
# Epoch 0, Step 10700, Loss: 1.5607
# Epoch 0, Step 10800, Loss: 1.4927
# Epoch 0, Step 10900, Loss: 1.5347
# Epoch 0, Step 11000, Loss: 1.5852
# Epoch 0, Step 11100, Loss: 1.4999
# Epoch 0, Step 11200, Loss: 1.5656
# Epoch 0, Step 11300, Loss: 1.5032
# Epoch 0, Step 11400, Loss: 1.5706
# Epoch 0, Step 11500, Loss: 1.4901
# Epoch 0, Step 11600, Loss: 1.4752
# Epoch 0, Step 11700, Loss: 1.5362
# Epoch 0, Step 11800, Loss: 1.4079
# Epoch 0, Step 11900, Loss: 1.5757
# Epoch 0, Step 12000, Loss: 1.4894
# Epoch 0, Step 12100, Loss: 1.4374
# Epoch 0, Step 12200, Loss: 1.4949
# Epoch 0, Step 12300, Loss: 1.4747
# Epoch 0, Step 12400, Loss: 1.3850
# Epoch 0, Step 12500, Loss: 1.5853
# Epoch 0, Step 12600, Loss: 1.4582
# Epoch 0, Step 12700, Loss: 1.6093
# Epoch 0, Step 12800, Loss: 1.4668
# Epoch 0, Step 12900, Loss: 1.4479
# Epoch 0, Step 13000, Loss: 1.5275
# Epoch 0, Step 13100, Loss: 1.5304
# Epoch 0, Step 13200, Loss: 1.3076
# Epoch 0, Step 13300, Loss: 1.5964
# Epoch 0, Step 13400, Loss: 1.5367
# Epoch 0, Step 13500, Loss: 1.4358
# Epoch 0, Step 13600, Loss: 1.4698
# Epoch 0, Step 13700, Loss: 1.5071
# Epoch 0, Step 13800, Loss: 1.5065
# Epoch 0, Step 13900, Loss: 1.3959
# Epoch 0, Step 14000, Loss: 1.4164
# Epoch 0, Step 14100, Loss: 1.6063
# Epoch 0, Step 14200, Loss: 1.5301
# Epoch 0, Step 14300, Loss: 1.5576
# Epoch 0, Step 14400, Loss: 1.4411
# Epoch 0, Step 14500, Loss: 1.5103
# Epoch 0, Step 14600, Loss: 1.5200
# Epoch 0, Step 14700, Loss: 1.4566
# Epoch 0, Step 14800, Loss: 1.4476
# Epoch 0, Step 14900, Loss: 1.4086
# Epoch 0, Step 15000, Loss: 1.5018
# Epoch 0, Step 15100, Loss: 1.4926
# Epoch 0, Step 15200, Loss: 1.5790
# Epoch 0, Step 15300, Loss: 1.3652
# Epoch 0, Step 15400, Loss: 1.4153
# Epoch 0, Step 15500, Loss: 1.4873
# Epoch 0, Step 15600, Loss: 1.3276
# Epoch 0, Step 15700, Loss: 1.5471
# Epoch 0, Step 15800, Loss: 1.3412
# Epoch 0, Step 15900, Loss: 1.4104
# Epoch 0, Step 16000, Loss: 1.4379
# Epoch 0, Step 16100, Loss: 1.3725
# Epoch 0, Step 16200, Loss: 1.4184
# Epoch 0, Step 16300, Loss: 1.4723
# Epoch 0, Step 16400, Loss: 1.3538
# Epoch 0, Step 16500, Loss: 1.5037
# Epoch 0, Step 16600, Loss: 1.6503
# Epoch 0, Step 16700, Loss: 1.4391
# Epoch 0, Step 16800, Loss: 1.4954
# Epoch 0, Step 16900, Loss: 1.5399
# Epoch 0, Step 17000, Loss: 1.5165
# Epoch 0, Step 17100, Loss: 1.5531
# Epoch 0, Step 17200, Loss: 1.5195
# Epoch 0, Step 17300, Loss: 1.5420
# Epoch 0, Step 17400, Loss: 1.5217
# Epoch 0, Step 17500, Loss: 1.4306
# Epoch 0, Step 17600, Loss: 1.4617
# Epoch 0, Step 17700, Loss: 1.4197
# Epoch 0, Step 17800, Loss: 1.5081
# Epoch 0, Step 17900, Loss: 1.4993
# Epoch 0, Step 18000, Loss: 1.5163
# Epoch 0, Step 18100, Loss: 1.4233
# Epoch 0, Step 18200, Loss: 1.4402
# Epoch 0, Step 18300, Loss: 1.4644
# Epoch 0, Step 18400, Loss: 1.4156
# Epoch 0, Step 18500, Loss: 1.3885
# Epoch 0, Step 18600, Loss: 1.4408
# Epoch 0, Step 18700, Loss: 1.4901
# Epoch 0, Step 18800, Loss: 1.4061
# Epoch 0, Step 18900, Loss: 1.3708
# Epoch 0, Step 19000, Loss: 1.3697
# Epoch 0, Step 19100, Loss: 1.4902
# Epoch 0, Step 19200, Loss: 1.5032
# Epoch 0, Step 19300, Loss: 1.4155
# Epoch 0, Step 19400, Loss: 1.4409
# Epoch 0, Step 19500, Loss: 1.4349
# Epoch 0, Step 19600, Loss: 1.3930
# Epoch 0, Step 19700, Loss: 1.4788
# Epoch 0, Step 19800, Loss: 1.4011
# Epoch 0, Step 19900, Loss: 1.4041
# Epoch 0, Step 20000, Loss: 1.3046
# Epoch 0, Step 20100, Loss: 1.5075
# Epoch 0, Step 20200, Loss: 1.5748
# Epoch 0, Step 20300, Loss: 1.4821
# Epoch 0, Step 20400, Loss: 1.5021
# Epoch 0, Step 20500, Loss: 1.3805
# Epoch 0, Step 20600, Loss: 1.5010
# Epoch 0, Step 20700, Loss: 1.4206
# Epoch 0, Step 20800, Loss: 1.5155
# Epoch 0, Step 20900, Loss: 1.4041
# Epoch 0, Step 21000, Loss: 1.4076
# Epoch 0, Step 21100, Loss: 1.4539
# Epoch 0, Step 21200, Loss: 1.4444
# Epoch 0, Step 21300, Loss: 1.4599
# Epoch 0, Step 21400, Loss: 1.3698
# Epoch 0, Step 21500, Loss: 1.4705
# Epoch 0, Step 21600, Loss: 1.3013
# Epoch 0, Step 21700, Loss: 1.3981
# Epoch 0, Step 21800, Loss: 1.4777
# Epoch 0, Step 21900, Loss: 1.3483
# Epoch 0, Step 22000, Loss: 1.5468
# Epoch 0, Step 22100, Loss: 1.4654
# Epoch 0, Step 22200, Loss: 1.3895
# Epoch 0, Step 22300, Loss: 1.4428
# Epoch 0, Step 22400, Loss: 1.4596
# Epoch 0, Step 22500, Loss: 1.3066
# Epoch 0, Step 22600, Loss: 1.3590
# Epoch 0, Step 22700, Loss: 1.4279
# Epoch 0, Step 22800, Loss: 1.2920
# Epoch 0, Step 22900, Loss: 1.2783
# Epoch 0, Step 23000, Loss: 1.3213
# Epoch 0, Step 23100, Loss: 1.3214
# Epoch 0, Step 23200, Loss: 1.3427
# Epoch 0, Step 23300, Loss: 1.3844
# Epoch 0, Step 23400, Loss: 1.4407
# Epoch 0, Step 23500, Loss: 1.4761
# Epoch 0, Step 23600, Loss: 1.4280
# Epoch 0, Step 23700, Loss: 1.4613
# Epoch 0, Step 23800, Loss: 1.4849
# Epoch 0, Step 23900, Loss: 1.4198
# Epoch 0, Step 24000, Loss: 1.4135
# Epoch 0, Step 24100, Loss: 1.4147
# Epoch 0, Step 24200, Loss: 1.4510
# Epoch 0, Step 24300, Loss: 1.5597
# Epoch 0, Step 24400, Loss: 1.5230
# Epoch 0, Step 24500, Loss: 1.4709
# Epoch 0, Step 24600, Loss: 1.4623
# Epoch 0, Step 24700, Loss: 1.3499
# Epoch 0, Step 24800, Loss: 1.3556
# Epoch 0, Step 24900, Loss: 1.4482
# Epoch 0, Step 25000, Loss: 1.3801
# Epoch 0, Step 25100, Loss: 1.4100
# Epoch 0, Step 25200, Loss: 1.4459
# Epoch 0, Step 25300, Loss: 1.3939
# Epoch 0, Step 25400, Loss: 1.4948
# Epoch 0, Step 25500, Loss: 1.3543
# Epoch 0, Step 25600, Loss: 1.3132
# Epoch 0, Step 25700, Loss: 1.4590
# Epoch 0, Step 25800, Loss: 1.3926
# Epoch 0, Step 25900, Loss: 1.4187
# Epoch 0, Step 26000, Loss: 1.4167
# Epoch 0, Step 26100, Loss: 1.4041
# Epoch 0, Step 26200, Loss: 1.4269
# Epoch 0, Step 26300, Loss: 1.4010
# Epoch 0, Step 26400, Loss: 1.3424
# Epoch 0, Step 26500, Loss: 1.4098
# Epoch 0, Step 26600, Loss: 1.3954
# Epoch 0, Step 26700, Loss: 1.4330
# Epoch 0, Step 26800, Loss: 1.5153
# Epoch 0, Step 26900, Loss: 1.4075
# Epoch 0, Step 27000, Loss: 1.4668
# Epoch 0, Step 27100, Loss: 1.3841
# Epoch 0, Step 27200, Loss: 1.2985
# Epoch 0, Step 27300, Loss: 1.4018
# Epoch 0, Step 27400, Loss: 1.3851
# Epoch 0, Step 27500, Loss: 1.4890
# Epoch 0, Step 27600, Loss: 1.3901
# Epoch 0, Step 27700, Loss: 1.4194
# Epoch 0, Step 27800, Loss: 1.4337
# Epoch 0, Step 27900, Loss: 1.2743
# Epoch 0, Step 28000, Loss: 1.4203
# Epoch 0, Step 28100, Loss: 1.2802
# Epoch 0, Step 28200, Loss: 1.4150
# Epoch 0, Step 28300, Loss: 1.3845
# Epoch 0, Step 28400, Loss: 1.3339
# Epoch 0, Step 28500, Loss: 1.4297
# Epoch 0, Step 28600, Loss: 1.2813
# Epoch 0, Step 28700, Loss: 1.3244
# Epoch 0, Step 28800, Loss: 1.3707
# Epoch 0, Step 28900, Loss: 1.3429
# Epoch 0, Step 29000, Loss: 1.3742
# Epoch 0, Step 29100, Loss: 1.4571
# Epoch 0, Step 29200, Loss: 1.2801
# Epoch 0, Step 29300, Loss: 1.3456
# Epoch 0, Step 29400, Loss: 1.3837
# Epoch 0, Step 29500, Loss: 1.3481
# Epoch 0, Step 29600, Loss: 1.3876
# Epoch 0, Step 29700, Loss: 1.3375
# Epoch 0, Step 29800, Loss: 1.3553
# Epoch 0, Step 29900, Loss: 1.4026
# Epoch 0, Step 30000, Loss: 1.3804
# Epoch 0, Step 30100, Loss: 1.4838
# Epoch 0, Step 30200, Loss: 1.3379
# Epoch 0, Step 30300, Loss: 1.4127
# Epoch 0, Step 30400, Loss: 1.3789
# Epoch 0, Step 30500, Loss: 1.4300
# Epoch 0, Step 30600, Loss: 1.3997
# Epoch 0, Step 30700, Loss: 1.3113
# Epoch 0, Step 30800, Loss: 1.3092
# Epoch 0, Step 30900, Loss: 1.3033
# Epoch 0, Step 31000, Loss: 1.4903
# Epoch 0, Step 31100, Loss: 1.3526
# Epoch 0, Step 31200, Loss: 1.4011
# Epoch 0, Step 31300, Loss: 1.4490
# Epoch 0, Step 31400, Loss: 1.4426
# Epoch 0, Step 31500, Loss: 1.3912
# Epoch 0, Step 31600, Loss: 1.3417
# Epoch 0, Step 31700, Loss: 1.4359
# Epoch 0, Step 31800, Loss: 1.3965
# Epoch 0, Step 31900, Loss: 1.3443
# Epoch 0, Step 32000, Loss: 1.3568
# Epoch 0, Step 32100, Loss: 1.4211
# Epoch 0, Step 32200, Loss: 1.3900
# Epoch 0, Step 32300, Loss: 1.4251
# Epoch 0, Step 32400, Loss: 1.4068
# Epoch 0, Step 32500, Loss: 1.4088
# Epoch 0, Step 32600, Loss: 1.2826
# Epoch 0, Step 32700, Loss: 1.4234
# Epoch 0, Step 32800, Loss: 1.3016
# Epoch 0, Step 32900, Loss: 1.3185
# Epoch 0, Step 33000, Loss: 1.4039
# Epoch 0, Step 33100, Loss: 1.5490
# Epoch 0, Step 33200, Loss: 1.4389
# Epoch 0, Step 33300, Loss: 1.3447
# Epoch 0, Step 33400, Loss: 1.3061
# Epoch 0, Step 33500, Loss: 1.3439
# Epoch 0, Step 33600, Loss: 1.3228
# Epoch 0, Step 33700, Loss: 1.3490
# Epoch 0, Step 33800, Loss: 1.4162
# Epoch 0, Step 33900, Loss: 1.2475
# Epoch 0, Step 34000, Loss: 1.3800
# Epoch 0, Step 34100, Loss: 1.2842
# Epoch 0, Step 34200, Loss: 1.3648
# Epoch 0, Step 34300, Loss: 1.3284
# Epoch 0, Step 34400, Loss: 1.4210
# Epoch 0, Step 34500, Loss: 1.3958
# Epoch 0, Step 34600, Loss: 1.4555
# Epoch 0, Step 34700, Loss: 1.4219
# Epoch 0, Step 34800, Loss: 1.4333
# Epoch 0, Step 34900, Loss: 1.3638
# Epoch 0, Step 35000, Loss: 1.3355
# Epoch 0, Step 35100, Loss: 1.4316
# Epoch 0, Step 35200, Loss: 1.3949
# Epoch 0, Step 35300, Loss: 1.4651
# Epoch 0, Step 35400, Loss: 1.4130
# Epoch 0, Step 35500, Loss: 1.2788
# Epoch 0, Step 35600, Loss: 1.3798
# Epoch 0, Step 35700, Loss: 1.4234
# Epoch 0, Step 35800, Loss: 1.3659
# Epoch 0, Step 35900, Loss: 1.4090
# Epoch 0, Step 36000, Loss: 1.4966
# Epoch 0, Step 36100, Loss: 1.3345
# Epoch 0, Step 36200, Loss: 1.2298
# Epoch 0, Step 36300, Loss: 1.3687
# Epoch 0, Step 36400, Loss: 1.3329
# Epoch 0, Step 36500, Loss: 1.4176
# Epoch 0, Step 36600, Loss: 1.4472
# Epoch 0, Step 36700, Loss: 1.4253
# Epoch 0, Step 36800, Loss: 1.3374
# Epoch 0, Step 36900, Loss: 1.3359
# Epoch 0, Step 37000, Loss: 1.2069
# Epoch 0, Step 37100, Loss: 1.4345
# Epoch 0, Step 37200, Loss: 1.3720
# Epoch 0, Step 37300, Loss: 1.5124
# Epoch 0, Step 37400, Loss: 1.4031
# Epoch 0, Step 37500, Loss: 1.4401
# Epoch 0, Step 37600, Loss: 1.3786
# Epoch 0, Step 37700, Loss: 1.2796
# Epoch 0, Step 37800, Loss: 1.2660
# Epoch 0, Step 37900, Loss: 1.3076
# Epoch 0, Step 38000, Loss: 1.3249
# Epoch 0, Step 38100, Loss: 1.3360
# Epoch 0, Step 38200, Loss: 1.3449
# Epoch 0, Step 38300, Loss: 1.2965
# Epoch 0, Step 38400, Loss: 1.4111
# Epoch 0, Step 38500, Loss: 1.2647
# Epoch 0, Step 38600, Loss: 1.5751
# Epoch 0, Step 38700, Loss: 1.3084
# Epoch 0, Step 38800, Loss: 1.4364
# Epoch 0, Step 38900, Loss: 1.2988
# Epoch 0, Step 39000, Loss: 1.5117
# Epoch 0, Step 39100, Loss: 1.3224
# Epoch 0, Step 39200, Loss: 1.2799
# Epoch 0, Step 39300, Loss: 1.3685
# Epoch 0, Step 39400, Loss: 1.3261
# Epoch 0, Step 39500, Loss: 1.4162
# Epoch 0, Step 39600, Loss: 1.2779
# Epoch 0, Step 39700, Loss: 1.3522
# Epoch 0, Step 39800, Loss: 1.3121
# Epoch 0, Step 39900, Loss: 1.3473
# Epoch 0, Step 40000, Loss: 1.3758
# Epoch 0, Step 40100, Loss: 1.3950
# Epoch 0, Step 40200, Loss: 1.3950
# Epoch 0, Step 40300, Loss: 1.4585
# Epoch 0, Step 40400, Loss: 1.2503
# Epoch 0, Step 40500, Loss: 1.3712
# Epoch 0, Step 40600, Loss: 1.4930
# Epoch 0, Step 40700, Loss: 1.3755
# Epoch 0, Step 40800, Loss: 1.2981
# Epoch 0, Step 40900, Loss: 1.5631
# Epoch 0, Step 41000, Loss: 1.2900
# Epoch 0, Step 41100, Loss: 1.3616
# Epoch 0, Step 41200, Loss: 1.3284
# Epoch 0, Step 41300, Loss: 1.3505
# Epoch 0, Step 41400, Loss: 1.3772
# Epoch 0, Step 41500, Loss: 1.3891
# Epoch 0, Step 41600, Loss: 1.2732
# Epoch 0, Step 41700, Loss: 1.4090
# Epoch 0, Step 41800, Loss: 1.4119
# Epoch 0, Step 41900, Loss: 1.3833
# Epoch 0, Step 42000, Loss: 1.3033
# Epoch 0, Step 42100, Loss: 1.3379
# Epoch 0, Step 42200, Loss: 1.2788
# Epoch 0, Step 42300, Loss: 1.3629
# Epoch 0, Step 42400, Loss: 1.2960
# Epoch 0, Step 42500, Loss: 1.2783
# Epoch 0, Step 42600, Loss: 1.3026
# Epoch 0, Step 42700, Loss: 1.3222
# Epoch 0, Step 42800, Loss: 1.3926
# Epoch 0, Step 42900, Loss: 1.3653
# Validation loss: 1.4347
# Generated text:
# He had into my dear child be prisoner's
# will-bling bad!  You are
# every went the man.
#
#
# MadWherwise by

# %%
context = torch.tensor([[char_to_idx['B']]], dtype=torch.long).to(device)  #Start with any letter
generated = context.tolist()[0]

model.eval()
with torch.no_grad():
    for _ in range(2000):  #Generate 2000 characters
        logits = model(context)  #(1, T, vocab_size)
        last_logits = logits[0, -1, :]  #(vocab_size,)
        probs = torch.softmax(last_logits, dim=-1)
        next_token = torch.multinomial(probs, num_samples=1)
        generated.append(next_token.item())
        context = torch.tensor([generated[-block_size:]], dtype=torch.long).to(device)

generated_text = ''.join(idx_to_char[idx] for idx in generated)
print("Generated text:")
print(generated_text)
# Out:
# Generated text:
# Buri and youth a more of
# ribbor staircade, to Darnay him, and Miss Pross?" as this leaving him, beard place out; and ever been step whethere Sydney,
# which seen hers in the
# mody as but.  And he comes.  But to be taverned them, this for the have
# been looked by
# the court, but of the heavy.
#
#
#
#
# VII
#
#
# It was no lixt wasted, by Lucie, and a garret; there was that little and
# his stood was, "how the neck.  Devil, I resumed in
# unconscious at him escores, and crossed in his hand across the work lying and were bling of the two tore ock had aland was as turn, and not?"
#
#
# "Mr. Don!  O Doctor Manette way,
# the purved, my cannot some pull under her herself.  I won't know to make yard her eyes restful
# of morestnoned picture, so have dislivered him.  The avail to Death."
#
#
# What the rain had a gyt, to property frightfulness; but, this quite was complimbed, swell who was stone of the trees well and like annoin, the side, all accompassed be his cheek room what it have been
# the shink,
# Defarge of Sheep, seated it is Pross, Jacques This at burning
# coming, all reliraction to them or other vechord any were keepers and his bodiling, the trovecomacing sunny like joluncs at
# these was in his glind walker actived the is treen, Monsieur that was a tax voices their way or
# dogs, before.  Roger Temple she not--eves like a passenger, and tore they appearing to take best eye not servace," retorted Miss Pross Pross, to fishful-st-street, do never whon they water, hope been incle.
# On drank you herebres me could the last has--like directed by one and all the only three lines, tears togethen!"
#
#
# Shumb--wrong air to the rain, and it into the finger, still hill.  Your may as and being down his getting his face, as a fresh.  In sound what I have bore the face, the night of bringing.
#
#
#
# He arging "The Vengeance curren_
# having my light that village of
# Gressedly beside.
#
#
# It will gate thus gut times, or Manette at the Concorrer, "these."
#
#
# "If, _I_shought the courtyard the village and showed thisher Woack to Stir
